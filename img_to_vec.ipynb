# %%
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
len(os.listdir('./images/'))
# Out:
# 918

# %%
img1=os.listdir('./images')[0]

# %%
img_gray = cv2.imread('./images/'+img1, cv2.IMREAD_GRAYSCALE)

# %%
img_color = cv2.imread('./images/'+img1)
img_color=cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)

# %%
img_gray.shape
# Out:
# (1800, 1800)

# %%
img_color.shape
# Out:
# (1800, 1800, 3)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_color)

# %%
cv2.resize()

# %%
# old stuff not using cv2

# %%
img_downscale = downscale_local_mean(img_gray, (10, 10))
img_downscale_color = downscale_local_mean(img_color, (10, 10, 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6428a1cd9708> in <module>
# ----> 1 img_downscale = downscale_local_mean(img_gray, (10, 10))
#       2 img_downscale_color = downscale_local_mean(img_color, (10, 10, 1))
#
# NameError: name 'downscale_local_mean' is not defined

# %%
img_downscale.shape

# %%
img_downscale_color.shape

# %%
plt.imshow(img_downscale, cmap='gray')

# %%
img_downscale_color = img_downscale_color.astype(int)

# %%
plt.imshow(img_downscale_color)
